# %%
from google.colab import drive
import os


drive.mount('/content/drive',force_remount=True)

os.chdir('/content/drive/MyDrive/ML')
os.listdir()
# Out:
# Mounted at /content/drive
# ['auto-mpg_sample.xml',
#  'scaling_comparison.png',
#  'correlation_matrix.png',
#  'pca_scree_plot.png',
#  'pca_components_analysis.png',
#  'pca_projection.png',
#  'auto-mpg.gsheet',
#  'cleaned.csv',
#  'indic-decibel-aqa-v0.1',
#  '1_ML.ipynb',
#  'auto-mpg.csv',
#  'auto-mpg1.csv',
#  'iris.ipynb',
#  'indic-decibel-aqa-v0.1.ipynb',
#  'wine.csv']

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import pandas as pd
from IPython.display import display

# %%
iris = load_iris()

# %%
param_grid = [{'kernel': ['rbf'],
'C': [0.001, 0.01, 0.1, 1, 10, 100],
'gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
{'kernel': ['linear'],
'C': [0.001, 0.01, 0.1, 1, 10, 100]}]
print("List of grids:\n{}".format(param_grid))
# Out:
# List of grids:
# [{'kernel': ['rbf'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}]

# %%
grid_search = GridSearchCV(SVC(), param_grid, cv=5)
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                           'gamma': [0.001, 0.01, 0.1, 1, 10, 100],
#                           'kernel': ['rbf']},
#                          {'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                           'kernel': ['linear']}])

# %%
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))


results = pd.DataFrame(grid_search.cv_results_)
display(results.T)
# Out:
# Best parameters: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best cross-validation score: 0.97
#                                                               0   ...                              41
# mean_fit_time                                           0.003252  ...                        0.000941
# std_fit_time                                            0.001559  ...                        0.000036
# mean_score_time                                         0.001837  ...                         0.00068
# std_score_time                                          0.000969  ...                        0.000004
# param_C                                                    0.001  ...                           100.0
# param_gamma                                                0.001  ...                             NaN
# param_kernel                                                 rbf  ...                          linear
# params             {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}  ...  {'C': 100, 'kernel': 'linear'}
# split0_test_score                                       0.347826  ...                        0.956522
# split1_test_score                                       0.347826  ...                        0.956522
# split2_test_score                                       0.363636  ...                             1.0
# split3_test_score                                       0.363636  ...                        0.909091
# split4_test_score                                       0.409091  ...                        0.954545
# mean_test_score                                         0.366403  ...                        0.955336
# std_test_score                                          0.022485  ...                        0.028764
# rank_test_score                                               27  ...                               8
#
# [16 rows x 42 columns]
